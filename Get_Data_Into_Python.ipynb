# %% [markdown]
# <a href="https://colab.research.google.com/github/Nokulunga77/Marketing/blob/main/Get_Data_Into_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import auth
import gspread
from google.auth import default

auth.authenticate_user()

# %%
creds, _ = default()

gc = gspread.authorize(creds)

worksheet = gc.open('Optily_2022_Updated').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
pd.DataFrame.from_records(rows)
# Out:
# [['', 'campaign_name', 'ad_name', 'adset_name', 'ctr', 'cpc', 'clicks', 'impressions', 'spend', 'frequency', 'reach', 'actions', 'cpp', 'cpm', 'date_start', 'date_stop', 'link_clicks', 'registrations', 'action_values'], ['0', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', '3.703704', '0.579474', '19', '513', '11.01', '1.032193', '497', "[{'action_type': 'photo_view', 'value': '8'}, {'action_type': 'post_reaction', 'value': '8'}, {'action_type': 'post_engagement', 'value': '16'}, {'action_type': 'page_engagement', 'value': '16'}]", '22.152918', '21.461988', '2022-04-06', '2022-04-06', '', '', ''], ['1', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', '1.160093', '3.925', '10', '862', '39.25', '1.027414', '839', "[{'action_type': 'photo_view', 'value': '3'}, {'action_type': 'post_reaction', 'value': '68'}, {'action_type': 'post_engagement', 'value': '71'}, {'action_type': 'page_engagement', 'value': '71'}]", '46.781883', '45.533643', '2022-04-07', '2022-04-07', '', '', ''], ['2', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', '4.105572', '1.343333', '42', '1023', '56.42', '1.052469', '972', "[{'action_type': 'comment', 'value': '2'}, {'action_type': 'photo_view', 'value': '10'}, {'action_type': 'post_reaction', 'value': '146'}, {'action_type': 'post_engagement', 'value': '158'}, {'action_type': 'page_engagement', 'value': '158'}]", '58.045267', '55.151515', '2022-04-08', '2022-04-08', '', '', ''], ['3', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', '4.99343', '0.788684', '76', '1522', '59.94', '1.065826', '1428', "[{'action_type': 'comment', 'value': '2'}, {'action_type': 'photo_view', 'value': '25'}, {'action_type': 'post_reaction', 'value': '145'}, {'action_type': 'post_engagement', 'value': '172'}, {'action_type': 'page_engagement', 'value': '172'}]", '41.97479', '39.382392', '2022-04-09', '2022-04-09', '', '', ''], ['4', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', '5.545113', '0.508898', '118', '2128', '60.05', '1.096342', '1941', "[{'action_type': 'photo_view', 'value': '27'}, {'action_type': 'post_reaction', 'value': '141'}, {'action_type': 'post_engagement', 'value': '168'}, {'action_type': 'page_engagement', 'value': '168'}]", '30.937661', '28.218985', '2022-04-10', '2022-04-10', '', '', ''], ['5', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', '6.25', '0.624842', '95', '1520', '59.36', '1.057024', '1438', "[{'action_type': 'comment', 'value': '3'}, {'action_type': 'photo_view', 'value': '16'}, {'action_type': 'post', 'value': '1'}, {'action_type': 'post_reaction', 'value': '137'}, {'action_type': 'post_engagement', 'value': '157'}, {'action_type': 'page_engagement', 'value': '157'}]", '41.279555', '39.052632', '2022-04-11', '2022-04-11', '', '', ''], ['6', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', 'Post: "Bright enough that you’ll need sunglasses 😎..."', '6.415094', '0.821765', '17', '265', '13.97', '1.019231', '260', "[{'action_type': 'post_reaction', 'value': '34'}, {'action_type': 'post_engagement', 'value': '34'}, {'action_type': 'page_engagement', 'value': '34'}]", '53.730769', '52.716981', '2022-04-12', '2022-04-12', '', '', ''], ['0', 'Instagram post: Bright enough that you’ll need...', 'In ...
#       0                                                  1   \
# 0                                             campaign_name
# 1      0  Post: "Bright enough that you’ll need sunglass...
# 2      1  Post: "Bright enough that you’ll need sunglass...
# 3      2  Post: "Bright enough that you’ll need sunglass...
# 4      3  Post: "Bright enough that you’ll need sunglass...
# ...   ..                                                ...
# 1683  75                                  optily_FB_EGY_BOF
# 1684  76                                  optily_FB_EGY_BOF
# 1685  77                                  optily_FB_EGY_BOF
# 1686  78                                  optily_FB_EGY_BOF
# 1687  79                                  optily_FB_EGY_BOF
#
#                                                      2   \
# 0                                               ad_name
# 1     Post: "Bright enough that you’ll need sunglass...
# 2     Post: "Bright enough that you’ll need sunglass...
# 3     Post: "Bright enough that you’ll need sunglass...
# 4     Post: "Bright enough that you’ll need sunglass...
# ...                                                 ...
# 1683                Life After EXPLOR Video - DE - Earn
# 1684                                  Video carousel DS
# 1685                                  Video carousel DE
# 1686                                  Video carousel DE
# 1687                                  Video carousel DS
#
#                                                      3         4         5   \
# 0                                            adset_name       ctr       cpc
# 1     Post: "Bright enough that you’ll need sunglass...  3.703704  0.579474
# 2     Post: "Bright enough that you’ll need sunglass...  1.160093     3.925
# 3     Post: "Bright enough that you’ll need sunglass...  4.105572  1.343333
# 4     Post: "Bright enough that you’ll need sunglass...   4.99343  0.788684
# ...                                                 ...       ...       ...
# 1683                           Life After EXPLORE Video  5.124836  0.506154
# 1684                              Selfie Video Carousel  1.169591     2.465
# 1685                              Selfie Video Carousel  1.536643  1.393077
# 1686                         Testimonial Video Carousel  4.428044  0.568333
# 1687                         Testimonial Video Carousel  3.243243  0.933333
#
#           6            7      8          9      10  \
# 0     clicks  impressions  spend  frequency  reach
# 1         19          513  11.01   1.032193    497
# 2         10          862  39.25   1.027414    839
# 3         42         1023  56.42   1.052469    972
# 4         76         1522  59.94   1.065826   1428
# ...      ...          ...    ...        ...    ...
# 1683      39          761  19.74   1.189063    640
# 1684       4          342   9.86     1.1875    288
# 1685      13          846  18.11   1.146341    738
# 1686      12          271   6.82   1.124481    241
# 1687       6          185    5.6   1.075581    172
#
#                                                      11         12         13  \
# 0                                               actions        cpp        cpm
# 1     [{'action_type': 'photo_view', 'value': '8'}, ...  22.152918  21.461988
# 2     [{'action_type': 'photo_view', 'value': '3'}, ...  46.781883  45.533643
# 3     [{'action_type': 'comment', 'value': '2'}, {'a...  58.045267  55.151515
# 4     [{'action_type': 'comment', 'value': '2'}, {'a...   41.97479  39.382392
# ...                                                 ...        ...        ...
# 1683  [{'action_type': 'link_click', 'value': '33'},...   30.84375  25.939553
# 1684  [{'action_type': 'link_click', 'value': '3'}, ...  34.236111  28.830409
# 1685  [{'action_type': 'link_click', 'value': '10'},...  24.539295  21.406619
# 1686  [{'action_type': 'link_click', 'value': '12'},...  28.298755  25.166052
# 1687  [{'action_type': 'link_click', 'value': '6'}, ...   32.55814   30.27027
#
#               14          15           16             17             18
# 0     date_start   date_stop  link_clicks  registrations  action_values
# 1     2022-04-06  2022-04-06
# 2     2022-04-07  2022-04-07
# 3     2022-04-08  2022-04-08
# 4     2022-04-09  2022-04-09
# ...          ...         ...          ...            ...            ...
# 1683  2022-06-01  2022-06-01           33
# 1684  2022-06-01  2022-06-01            3
# 1685  2022-06-01  2022-06-01           10
# 1686  2022-06-01  2022-06-01           12
# 1687  2022-06-01  2022-06-01            6
#
# [1688 rows x 19 columns]
